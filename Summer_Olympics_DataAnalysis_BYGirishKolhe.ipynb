# %% [markdown]
# # Summer Olympics Data Analysis Assignment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("summer.csv")
df.head()
# Out:
#    Year    City     Sport Discipline             Athlete Country Gender  \
# 0  1896  Athens  Aquatics   Swimming       HAJOS, Alfred     HUN    Men
# 1  1896  Athens  Aquatics   Swimming    HERSCHMANN, Otto     AUT    Men
# 2  1896  Athens  Aquatics   Swimming   DRIVAS, Dimitrios     GRE    Men
# 3  1896  Athens  Aquatics   Swimming  MALOKINIS, Ioannis     GRE    Men
# 4  1896  Athens  Aquatics   Swimming  CHASAPIS, Spiridon     GRE    Men
#
#                         Event   Medal
# 0              100M Freestyle    Gold
# 1              100M Freestyle  Silver
# 2  100M Freestyle For Sailors  Bronze
# 3  100M Freestyle For Sailors    Gold
# 4  100M Freestyle For Sailors  Silver

# %% [markdown]
# ### 1. In how many cities Summer Olympics is held so far?

# %%
oly_city = df['City'].unique()
l =[]
for i in oly_city:
    l.append(i)
print("Cities were olympics held: ",l)
print("\nTotal number of cities: ",len(oly_city))
# Out:
# Cities were olympics held:  ['Athens', 'Paris', 'St Louis', 'London', 'Stockholm', 'Antwerp', 'Amsterdam', 'Los Angeles', 'Berlin', 'Helsinki', 'Melbourne / Stockholm', 'Rome', 'Tokyo', 'Mexico', 'Munich', 'Montreal', 'Moscow', 'Seoul', 'Barcelona', 'Atlanta', 'Sydney', 'Beijing']
#
# Total number of cities:  22

# %% [markdown]
# ### 2. Which sport is having most number of Gold Medals so far? (Top 5)

# %%
goldMedals = []
g1 = df[df['Medal'] == 'Gold']
for i in g1['Sport'].unique():
    goldMedals.append([i,len(g1[g1['Sport']==i])])
g22 = pd.DataFrame(goldMedals,columns = ['Sports','Gold']).sort_values(by='Gold', ascending=False)
g2 = pd.DataFrame(goldMedals,columns = ['Sports','Gold']).sort_values(by='Gold', ascending=False).head()
g22.plot(x = 'Sports', y = 'Gold', kind = 'bar', figsize = (7,5),color="orange",title="Sports is having most number of Gold Medals")
g2.plot(x = 'Sports', y = 'Gold', kind = 'bar', figsize = (7,5),color="orange",title="TOP 5 Sports is having most number of Gold Medals")
g2L = g2.values #converting it to list
print("{} Sport has Won {} Number of Gold Medals.".format(g2L[0][0],g2L[0][1]))
g2
# Out:
# Aquatics Sport has Won 1421 Number of Gold Medals.
#         Sports  Gold
# 0     Aquatics  1421
# 1    Athletics  1215
# 17      Rowing   890
# 4   Gymnastics   820
# 3      Fencing   552

# %% [markdown]
# ### 3. Which sport is having most number of medals so far? (Top 5)

# %%
allMedals=[]
for m in df['Sport'].unique():
    allMedals.append([m,len(df[df['Sport'] == m])])
m11 = pd.DataFrame(allMedals,columns = ['Sports','Medals']).sort_values(by='Medals', ascending=False)
m11.plot(x = 'Sports',y='Medals',color='green',kind='bar',figsize = [7,5],title='Sports is having most number of medals')
m1 = pd.DataFrame(allMedals,columns = ['Sports','Medals']).sort_values(by='Medals', ascending=False).head()
m1.plot(x = 'Sports',y='Medals',color='green',kind='bar',figsize = [7,5],title='TOP 5 Sports is having most number of medals')
print("{} Sport has won {} Medals(Gold, Silver, Bronze)".format(m1['Sports'][0],m1['Medals'][0]))
m1
# Out:
# Aquatics Sport has won 4170 Medals(Gold, Silver, Bronze)
#         Sports  Medals
# 0     Aquatics    4170
# 1    Athletics    3638
# 17      Rowing    2667
# 4   Gymnastics    2307
# 3      Fencing    1613

# %% [markdown]
# ### 4. Which player has won most number of medals? (Top 5)

# %%
plyName =[]
for p1 in df['Athlete'].unique():
    plyName.append([p1,len(df[df['Athlete'] == p1])])
p2 = pd.DataFrame(plyName,columns = ['Athletes','Medals']).sort_values(by='Medals', ascending=False).head()
p2.plot(x = 'Athletes',y='Medals',kind='bar',figsize = [7,5],title="TOP 5 Player Winning Most Medals in all Olympics")
p2L = p2.values #converting it to list
print("{} has won {} number of Medals(Gold, Silver, Bronze)".format(p2L[0][0],p2L[0][1]))
p2
# Out:
# PHELPS, Michael has won 22 number of Medals(Gold, Silver, Bronze)
#                    Athletes  Medals
# 18640       PHELPS, Michael      22
# 7197       LATYNINA, Larisa      18
# 9948     ANDRIANOV, Nikolay      15
# 6591           ONO, Takashi      13
# 5103   MANGIAROTTI, Edoardo      13

# %% [markdown]
# ### 5. Which player has won most number Gold Medals of medals? (Top 5)

# %%
pgName =[]
pg1 = df[df['Medal'] == 'Gold']
for plgold in pg1['Athlete'].unique():
    pgName.append([plgold,len(pg1[pg1['Athlete']==plgold])])
pg2 = pd.DataFrame(pgName,columns = ['Athletes','GoldMedals']).sort_values(by='GoldMedals', ascending=False).head()
pg2.plot(x = 'Athletes',y='GoldMedals',kind='bar',figsize = [7,5],title="TOP 5 Player Winning Most Gold Medals in all Olympics",color='orange')
pg2L=pg2.values #converting it to list
print("{} has won {} number of Gold Medals".format(pg2L[0][0],pg2L[0][1]))
pg2
# Out:
# PHELPS, Michael has won 18 number of Gold Medals
#               Athletes  GoldMedals
# 6851   PHELPS, Michael          18
# 3320       SPITZ, Mark           9
# 2714  LATYNINA, Larisa           9
# 4630       LEWIS, Carl           9
# 907       NURMI, Paavo           9

# %% [markdown]
# ### 6. In which year India won first Gold Medal in Summer Olympics?

# %%
cou = df[df['Country'] == "IND"]
couG = cou[cou['Medal']=='Gold']
y = couG['Year'].unique()
spo = couG['Sport'].unique()
print("India Won first Olympic Gold Medal in {} at Year {} ".format(spo[0],y[0]))
# Out:
# India Won first Olympic Gold Medal in Hockey at Year 1928

# %% [markdown]
# ### 7. Which event is most popular in terms on number of players? (Top 5)

# %%
events=[]
for e in df['Event'].unique():
    events.append([e,len(df[df['Event'] == e])])
eve1 = pd.DataFrame(events,columns = ['Athletes','Events']).sort_values(by='Events', ascending=False).head()
eve1.plot(x = 'Athletes',y='Events',kind='bar',figsize = [7,5],title="TOP 5 Most Event played by player in all Olympics")
eveL = eve1.values #converting it to list
print("{} is the event were played by {} players.".format(eveL[0][0],eveL[0][1]))
eve1
# Out:
# Football is the event were played by 1497 players.
#              Athletes  Events
# 80           Football    1497
# 176            Hockey    1422
# 138  Team Competition    1147
# 327        Basketball    1012
# 337          Handball     973

# %% [markdown]
# ### 8. Which sport is having most female Gold Medalists? (Top 5)

# %%
femaleSport=[]
pg1 = df[df['Medal'] == 'Gold']
pfg = pg1[pg1['Gender'] == 'Women']
for w in pfg['Sport'].unique():
    femaleSport.append([w,len(pfg[pfg['Sport'] == w])])
pfg2 = pd.DataFrame(femaleSport,columns = ['Sports','GoldMedals']).sort_values(by='GoldMedals', ascending=False).head()
pfg2.plot(x = 'Sports',y='GoldMedals',kind='bar',color='yellow',figsize = [7,5],title="Top 5 Sports were Female Players Winning Most Gold Medals in all Olympics")
pfg2L=pfg2.values #converting it to list
print("{} Sport were female has won {} Gold Medals".format(pfg2L[0][0],pfg2L[0][1]))
pfg2
# Out:
# Aquatics Sport were female has won 589 Gold Medals
#         Sports  GoldMedals
# 4     Aquatics         589
# 7    Athletics         389
# 8   Gymnastics         268
# 14      Rowing         217
# 11  Volleyball         166

# %% [markdown]
# # Thank YOU
